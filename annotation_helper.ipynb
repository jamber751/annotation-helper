# %%
import os
import sys
import numpy as np
import pandas as pd
import scanpy as sc
import yaml
from IPython.display import display, HTML

# %%
# settings to display all columns + print result
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 1000)

# %% [markdown]
# # Generate the database

# %%
# Create place to store the database
database = []

# Specify walk_dir
walk_dir = 'auto-annotation-md'

# Counter check for .yaml file (should be 215)
n = 0

# Make walk_dir absolute
walk_dir = os.path.abspath(walk_dir)

print('walk_dir (absolute) = ' + walk_dir)

for root, subdirs, files in os.walk(walk_dir):
    list_file_path = os.path.join(root, 'my-directory-list.txt')
    with open(list_file_path, 'wb') as list_file:
        for filename in files:
            file_path = os.path.join(root, filename)
            
            with open(file_path, 'r') as stream:
                
                if file_path[-5:] == '.yaml':
                    content = stream.read()
                    database.append(list(yaml.load_all(content.split("---", 1)[0])))
# Out:
# walk_dir (absolute) = /Users/jrrrrr/Desktop/annotation/auto-annotation-md
# /Users/jrrrrr/miniconda3/envs/scanpy/lib/python3.6/site-packages/ipykernel_launcher.py:25: YAMLLoadWarning: calling yaml.load_all() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
database
# Out:
# [[{'name': 'Glutamatergic 2',
#    'abbreviation': '@VGLUT2',
#    'definition': '+Slc17a6',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': ['Glutamatergic neurotransmission']}],
#  [{'name': 'Cholinergic',
#    'abbreviation': '@CHOL',
#    'definition': '+Chat +Slc5a7',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': ['Cholinergic neurotransmission']}],
#  [{'name': 'Glutamatergic 3',
#    'abbreviation': '@VGLUT3',
#    'definition': '+Slc17a8',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'synonyms': ['Glutamatergic neurotransmission'],
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Serotonergic',
#    'abbreviation': '@SER',
#    'definition': '+Tph2 +Fev',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Adrenergic',
#    'abbreviation': 'ADR',
#    'definition': '+Dbh +Ddc +Th +Pnmt',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': ['Adrenergic neurotransmission']}],
#  [{'name': 'Noradrenergic',
#    'abbreviation': '@NOR',
#    'definition': '+Dbh +Ddc +Th',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': ['Noradrenergic neurotransmission']}],
#  [{'name': 'Rhombomeres r3 r5',
#    'abbreviation': '@Hr3r5',
#    'definition': '+Hoxa2 +Hoxb2 +Egr2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Patterning Hindbrain',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'GABAergic and Glutamatergic VGLUT1',
#    'abbreviation': '@GABAGLUT1',
#    'definition': '+Gad2 +Slc32a1 -Slc6a5 +Slc17a7',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'GABAergic',
#    'abbreviation': '@GABA',
#    'definition': '+Gad2 +Slc32a1 -Slc6a5',
#    'go': '0051932 (synaptic transmission, GABAergic)',
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': ['Inhibitory neurotransmission']}],
#  [{'name': 'Hindbrain rombomere 4',
#    'abbreviation': '@HCNv',
#    'definition': '+Vgll3 +Fst +Hoxb1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Patterning Spinal Hindbrain',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Glycinergic',
#    'abbreviation': '@GLY',
#    'definition': '+Slc32a1 +Slc6a5',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': ['Glycinergic neurotransmission']}],
#  [{'name': 'Dopaminergic',
#    'abbreviation': '@DA',
#    'definition': '+Th +Ddc +Slc6a3',
#    'go': '0001963 (synaptic transmission, dopaminergic)',
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Glutamatergic 1',
#    'abbreviation': '@VGLUT1',
#    'definition': '+Slc17a7',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'synonyms': ['Glutamatergic neurotransmission'],
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Gonadotropin-releasing hormone',
#    'abbreviation': '@GNRH',
#    'definition': '+Gnrh1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'Vasopressin',
#    'abbreviation': '@AVP',
#    'definition': '+Avp +Ebf3',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'Oxytocin',
#    'abbreviation': '@OXT',
#    'definition': '+Oxt +Lhx2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'Agouti-related peptide',
#    'abbreviation': '@AGRP',
#    'definition': '+Agrp +Npy',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'Thyrotropin-releasing hormone',
#    'abbreviation': '@TRH',
#    'definition': '+Trh +Adcyap1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'Orexin-releasing hormone',
#    'abbreviation': '@HCRT',
#    'definition': '+Hcrt',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'Pro-opiomelanocortin peptide',
#    'abbreviation': '@POMC',
#    'definition': '+Pomc +Slc32a1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1}],
#  [{'name': 'X inactivation',
#    'abbreviation': '@XIN',
#    'definition': '+Xist +Tsix',
#    'categories': 'Female',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'synonyms': None}],
#  [{'name': 'Claudins',
#    'abbreviation': '@Cldn',
#    'definition': '+Cldn3 +Cldn4 +Cldn6 +Cldn7',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': None,
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Early Neural Tube',
#    'abbreviation': '@EarlyNT',
#    'definition': '+Lin28a +Ifitm1 +Sox2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Neuroepithelial',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Immediate early gene activation',
#    'abbreviation': '@IEG',
#    'definition': '+Fos +Jun +Egr1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': None,
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Angiogenesis activation',
#    'abbreviation': '@Angio',
#    'definition': '+Gkn3 +Sema3g',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Early Spinal Cord',
#    'abbreviation': '@SpnlC',
#    'definition': '+Sfrp5 +Cpn1 +1700011H14Rik',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Hindbrain Spinal Patterning',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Alar Thalamus',
#    'abbreviation': '@p2AL',
#    'definition': '+Irx5 +Irx3 +Tal2 -Wnt8b -Rspo2 -Dlx5 -Nkx2-9 -Trh',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Forebrain',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Marginal MHB',
#    'abbreviation': '@MHBm',
#    'definition': '+Wnt1 +Rspo1 -Emx1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Patterning Midbrain Ectodermal Neuroectodermal Neuronal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Posterior Neural Tube',
#    'abbreviation': '@PNT',
#    'definition': '+T +Gbx2 -Otx2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Patterning',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Caudal Type Homeobox',
#    'abbreviation': '@Cdx',
#    'definition': '+Cdx4 +Cdx1 +Cdx2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Endomesodermal Neuroectodermal Neuronal Radialglial',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neural fold',
#    'abbreviation': '@NFold',
#    'definition': '+Wnt1 +Msx2 +Msx1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Patterning Ectodermal Neuroectodermal NeuralCrest',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Pallium',
#    'abbreviation': '@Pall',
#    'definition': '+Pax6 +Emx1 -Gsx2 -Six6',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Roof plate of Thalamus',
#    'abbreviation': '@p2RP',
#    'definition': '+Shox2 +Olig3 +Tcf7l2 +Barhl2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Forebrain',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Rostral Diencephalon',
#    'abbreviation': '@RDie',
#    'definition': '+Atoh1 +Barhl1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Midbrain-Hindbrain boundary rostral',
#    'abbreviation': '@MHBr',
#    'definition': '+Otx2 +En1 +Pax5 +Hes3 -Fgf17',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Midbrain Patterning Ectodermal Neuroectodermal Neuronal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Caudal Hindbrain and Cervical Spinal Cord',
#    'abbreviation': '@CHind',
#    'definition': '+Skor1 +Lbx1 +Pax2 +Tfap2a',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Caudal Hox Genes',
#    'abbreviation': '@HoxCaud',
#    'definition': '+Hoxa7 +Hoxb9 +Hoxc8 +Hoxa9',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Endomesodermal Neuroectodermal Neuronal Radialglial',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Rhombomeres r3 r5',
#    'abbreviation': '@Hr2Sc',
#    'definition': '+Nkx2-9 +Tgfb2 +Foxa2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Patterning Spinal Hindbrain',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Early Dorsal Hindbrain and Spinal Cord',
#    'abbreviation': '@EDrCau',
#    'definition': '+Msx3 +Msx1 +Msx2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Hindbrain Spinal Dorsal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Habenula and tissues around Pineal gland',
#    'abbreviation': '@Habe',
#    'definition': '+Tesc +Nwd2 +Cpne4 +Necab2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Developing Diencephalon',
#    'abbreviation': '@Dienc',
#    'definition': '+Emx2 +Barhl2 +Pax6 -Robo3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Forebrain Diencephalon',
#    'version': 3,
#    'synonyms': None}],
#  [{'name': 'Eye Field cells',
#    'abbreviation': '@Eye',
#    'definition': '+Lhx2 +Rax +Six3 +Pax6',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Forebrain',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Prethalamus and Posterior Pallium',
#    'abbreviation': '@pTh',
#    'definition': '+Rspo2 +Rspo3 +Wnt7b +Wnt8b',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Posterior dorsal Midbrain',
#    'abbreviation': '@PMid',
#    'definition': '+Tfap2d +Pou4f3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Midbrain',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Midbrain-Hindbrain boundary wide area',
#    'abbreviation': '@MHBw',
#    'definition': '+En1 +Pax2 +Pax5 +Pax8',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Hindbrain Midbrain Patterning Ectodermal Neuroectodermal Neuronal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Midbrain-Hindbrain boundary caudal',
#    'abbreviation': '@MHBc',
#    'definition': '+Fgf17 +En1 +Pax5 +Hes3 -Otx2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Hindbrain Patterning Ectodermal Neuroectodermal Neuronal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Dorsal (rostral) Midbrain and other regions',
#    'abbreviation': '@DMid',
#    'definition': '+Sox14 +Asic4',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Mesenchymal cell',
#    'abbreviation': '@Msn',
#    'definition': '+Twist2 +Foxc1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Blood Mononuclear system cell',
#    'abbreviation': '@BMono',
#    'definition': '+Fcer1g +C1qb',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Cell cycle',
#    'abbreviation': '@CC',
#    'definition': '+Cdk1 +Top2a +Cenpf',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Cycling',
#    'version': 1,
#    'synonyms': ['Proliferation']}],
#  [{'name': 'Oligodendrocyte lineage',
#    'abbreviation': '@OL',
#    'definition': '+Sox10 +Plp1 +Mog',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Commissural Plate',
#    'abbreviation': '@CoP',
#    'definition': '+Fgf8 +Fgf18 +Fgf17',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Organizer',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Radialglia of a Midbrain Wnt expressing organizer',
#    'abbreviation': 'RglMdOr',
#    'definition': '+Wnt9a +Rspo3 +Wnt1 +Rspo1 +Pax3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Midbrain Organizer',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Cortical Hem',
#    'abbreviation': '@Hem',
#    'definition': '+Lhx5 +Wnt8b +Bmp7',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Organizer',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Gingival Fibroblasts',
#    'abbreviation': 'GUM',
#    'definition': '+Barx1 +Dlx5',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal Face',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Cardiomyocytes',
#    'abbreviation': 'CARD',
#    'definition': '+Myh6 +Tnni3 +Tnnt2 +Actc1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Perivascular macrophage',
#    'abbreviation': 'PVM',
#    'definition': '+Pf4 +Mrc1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Microglia',
#    'abbreviation': 'MGL',
#    'definition': '+Hexb +Aif1',
#    'go': None,
#    'shogoin': '116m',
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'wikipedia': 'https://en.wikipedia.org/wiki/Microglia',
#    'predecessors': None}],
#  [{'name': 'Erythrocyte',
#    'abbreviation': 'ERY',
#    'definition': '+Hba-a2 +Alas2',
#    'go': None,
#    'shogoin': '014m',
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': 'Red blood cell'}],
#  [{'name': 'Platellet related cell',
#    'abbreviation': 'PLAT',
#    'definition': '+Ppbp +Gp9 +Gp5 +Gp1bb',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Vascular endothelial cell',
#    'abbreviation': 'VEC',
#    'definition': '+Cldn5 +Flt1 +Ly6c1 +Slc38a5',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Fenestrated Capillary cell',
#    'abbreviation': 'VEC-FC',
#    'definition': '+Cldn5 +Flt1 +Plvap +Hapln1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Pericyte',
#    'abbreviation': 'PERI',
#    'definition': '+Rgs5 -Kdr',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Vascular smooth muscle cell',
#    'abbreviation': 'VSM',
#    'definition': '+Acta2 +Actg2 +Myh11 -Ly6c1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Vascular and leptomeningeal cell',
#    'abbreviation': 'VLMC',
#    'definition': '+Lum +Dcn +Pdgfra',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Meningeal fibroblasts',
#    'abbreviation': 'MFIB',
#    'definition': '+Mgp +Lypd2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Early Hematopoietic Progenitor',
#    'abbreviation': 'EHProg',
#    'definition': '+Gata1 +Gata2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Extraembrionic Visceral Endoderm',
#    'abbreviation': 'ExVE',
#    'definition': '+Vil1 +Apom +Soat2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Trophoblast (Extrambryonic Ectoderm)',
#    'abbreviation': 'Tropho',
#    'definition': '+Elf5 +Tex19.1 +Nr0b1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Glycinergic neurons expressing Skor1',
#    'abbreviation': 'Glyc-Skor1',
#    'definition': '+Skor1 +Nrxn3 +Slc6a5 -Otp',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Cerebellar Neural Progenitors',
#    'abbreviation': 'NProgCrbl',
#    'definition': '+Neurog2 +Smoc1 +Ascl1 +Ptf1a -Neurog1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Dlx genes',
#    'abbreviation': 'Dlx',
#    'definition': '+Dlx1 +Dlx2 +Dlx5',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Astrocytes Type 3',
#    'abbreviation': 'Astro3',
#    'definition': '+Veph1 +Myl9 -Foxj1 +Pla2g7 -Serpinf1',
#    'categories': 'Ectodermal Neuroectodermal'}],
#  [{'name': 'Epithalamus',
#    'abbreviation': 'epiTh',
#    'definition': '+Tcf7l2 +Pou4f1 +Nwd2',
#    'categories': 'Ectodermal Neuroectodermal'}],
#  [{'name': 'Cranial Neural Crest Cell',
#    'abbreviation': 'CNC',
#    'definition': '+Dlx2 +Plp1 +Sox10',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal NeuralCrest Face',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Hindbrain Serotonergic Neurons',
#    'abbreviation': 'HinSert',
#    'definition': '+Gchfr +Fev +Gata3 +Cryba2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Astrocytes Type 2',
#    'abbreviation': 'Astro2',
#    'definition': '+Slc7a10 +Htra1 -Foxj1 -Serpinf1',
#    'categories': 'Ectodermal Neuroectodermal'}],
#  [{'name': 'Neural Progenitors Hindbrain 1',
#    'abbreviation': 'NProgH1',
#    'definition': '+Neurog1 +Neurog2 +Vsx1 +Alpl',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Thalamus 1',
#    'abbreviation': 'Th1',
#    'definition': '+Rora +Prox1 +Nr2f1 +Prkch',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Radialglia-like 2 Midbrain',
#    'abbreviation': 'RglM2',
#    'definition': '+Tnc +Ednrb +Clu +Ndrg2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Nasal Epithelium',
#    'abbreviation': 'Nose',
#    'definition': '+Aldh1a3 +Pdgfc -Pyy',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Hindbrain Excitatory Progenitor',
#    'abbreviation': 'HinNProg',
#    'definition': '+Ntf3 +Sp5 +Tlx3',
#    'related': 'HinEx2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Ventricular Zone',
#    'abbreviation': 'VZone',
#    'definition': '+Cdon +E2f5 +Hmgn2 +Neurog2 +Notch1 +Tead2 +Tgif2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Interneurons from CGE',
#    'abbreviation': 'CGEInt',
#    'definition': '+Adarb2 +Htr3a +Dlx1 +Dlx2 +Dlx5',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Midbrain Dopaminergic Neuron',
#    'abbreviation': 'mDA',
#    'definition': '+Lmx1a +Pitx3 +Nr4a2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Radialglia Midbrain Hindbrain',
#    'abbreviation': 'RglMHb',
#    'definition': '+Trip6 +Sfrp2 +Vim -Kdr -Rgs5 -Utf1 -Cldn4 -Mpz',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Lateral hypothalamus',
#    'abbreviation': 'Hypo-L',
#    'definition': '+Hmx2 +Hmx3 +Gal',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Early Telencephalic Excitatory Neurons',
#    'abbreviation': 'eTEGLU',
#    'definition': '+Crym +Cryab +Cnih3 +Opcml +Slit3',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Tanycyte',
#    'abbreviation': 'EPN-T',
#    'definition': '+Sox2 +Vim +Rax',
#    'categories': 'Ectodermal Neuroectodermal'}],
#  [{'name': 'Developing CA cells in the hippocampus',
#    'abbreviation': 'HC-CA-Dev',
#    'definition': '+Crym +Grp +Slit3 +Nrp2',
#    'categories': 'Ectodermal Neuroectodermal'}],
#  [{'name': 'Putative Teactum and Cerebellar Progenitors',
#    'abbreviation': 'TcCbProg',
#    'definition': '+Cnpy1 +Hes3 +Trh +Etv4',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Midbrain',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Neural Progenitors',
#    'abbreviation': 'NProg',
#    'definition': '+Igfbpl1 +Neurog2 +Neurog1 -Nhlh2 -Onecut2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Hypothalamic Peptidergic developmental',
#    'abbreviation': 'eHyPep',
#    'definition': '+Otp +Sim1 +Chst8 +Fezf1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Prethalamus',
#    'abbreviation': 'preTh',
#    'definition': '+Fign +Ramp3 +Meis2 +Esrrg',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Delaminating Neural Crest',
#    'abbreviation': 'DelaNC',
#    'definition': '+Dlx5 +Hopx +Prrx1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal NeuralCrest Face',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Reactive Astrocyte',
#    'abbreviation': 'rAC',
#    'definition': '+Gfap +Pla2g3  +Cidea',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Radialglialike',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Developmental Interneuron midbrain type 2',
#    'abbreviation': 'IntMid2',
#    'definition': '+Nfix +Nfib +Pcp4 +Gad1 -Npy -Tal2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Neuron hindbrain V2b interneurons',
#    'abbreviation': 'IntV2b',
#    'definition': '+Gata3 +Gata2 +Tal1 +Sox14 +Rpp25 -Shox2 -Tcf7l2',
#    'relation': 'MGabaProg NbMid11',
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Radialglia-like 2',
#    'abbreviation': 'Rgl2',
#    'definition': '+Tnc +Ednrb +Slc6a11',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'D1 medium spiny neurons, striatum',
#    'abbreviation': 'MSN4',
#    'definition': '+Isl1 +Ptprg +Zfp804a +Pou3f1',
#    'related': 'MSN1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Developmental Interneuron hippocampus-like type 1',
#    'abbreviation': 'IntHc1',
#    'definition': '+Gad1 +Nrxn3 +Nxph1 +Lhx6 +Sst +Maf',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Hindbrain Excitatory type 1',
#    'abbreviation': 'HinEx1',
#    'definition': '+Nfix +Barhl1 +Crabp1 +Neto1 +Adcyap1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Dorsal Thalamic tier Excitatory type 1',
#    'abbreviation': 'ThaEx1',
#    'definition': '+Gbx2 +Tcf7l2 +Pou2f2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Prethalamus type 2',
#    'abbreviation': 'preTh2',
#    'definition': '+Lhx1 +Pax6 +Syt4 +Fam19a1 +Rcn1',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Gabaergic neurons cerebellar c2v',
#    'abbreviation': 'Glyc-Cblc2',
#    'definition': '+Pax2 +Otp +Adarb2 +Gad1 +Gad2 -Skor1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Olfactory bulb neuroblast 1',
#    'abbreviation': 'OBNbl1',
#    'definition': '+Nts +Cntn4 +Mast4 +Cnih3 +Tnr',
#    'related': 'OBNbl2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Rhombomeric Neural Crest',
#    'abbreviation': 'HinNC',
#    'definition': '+Hoxb2 +Hoxa2 +Sox10 +Plp1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal NeuralCrest',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Hindbrain Radialglia3-like cell',
#    'abbreviation': 'HRgl3',
#    'definition': '+Fgl2 +Ntn1 +Pdyn',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Radialglialike',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Neuronal intermediate progenitor cell',
#    'abbreviation': 'NIPC',
#    'definition': '+Eomes +Neurog2 +Mfng +Btbd17',
#    'related': 'NIPC1 NIPC2',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Neuronal Progenitors Forebrain',
#    'abbreviation': 'NProgF',
#    'definition': '+Dlx2 +Ascl1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Radialglialike',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Migratory pyramidal',
#    'abbreviation': 'MigPyr',
#    'definition': '+Unc5d +Lsamp +Sema3c +Pdzrn3',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Deep layer',
#    'abbreviation': 'LDeep',
#    'definition': '+Hs3st4 +Tle4 +Igfbp3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Midbrain Inhibitory Progenitors',
#    'abbreviation': 'MGabaProg',
#    'definition': '+Shox2 +Ascl1 +Dll3 +Tal2 -Six3 -Cartpt',
#    'relation': 'IntV2b NbMid11',
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuralprogenitor',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Radialglia-like 2c',
#    'abbreviation': 'Rgl2c',
#    'definition': '+Olig1 +Olig2 +Dll3 -Aqp4 -Tnc',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Neural Progenitor Mediolateral 1',
#    'abbreviation': 'NProgML1',
#    'definition': '+Nkx6-2 +Ptx3 +Fzd7 -Fgf8',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Anterior NeuroEctoderm',
#    'abbreviation': 'ANE',
#    'definition': '+Hesx1 +Six3 +Foxd4',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Forebrain',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Developmental Interneuron hindbrain type 1',
#    'abbreviation': 'IntHin1',
#    'definition': '+Foxp2 +Rora +Islr2 +Fgf3',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Mammillary region of the hypothalamus',
#    'abbreviation': 'MB',
#    'definition': '+Foxb1 +Cck +Uncx +Lhx1os',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Radialglia',
#    'abbreviation': 'Rgl',
#    'definition': '+Hes1 +Vim +Sox2 -Kdr -Rgs5 -Utf1 -Cldn4 -Mpz -Plp1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Radialglialike',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Hindbrain Excitatory type 2',
#    'abbreviation': 'HinEx2',
#    'definition': '+Reln +Sp5 +Pdgfc +Ccnd2 +Pcsk9',
#    'related': 'HinNProg2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Olfactory bulb neuroblast 2',
#    'abbreviation': 'OBNbl2',
#    'definition': '+Etv1 +Brca1 +Nebl +Barhl2 -Cntn4',
#    'related': 'OBNbl1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Midbrain Radialglia3',
#    'abbreviation': 'MRgl3',
#    'definition': '+Ntn1 +Ccdc3 +Sulf1 +Shh +Foxa2',
#    'related': 'HRgl3',
#    'categories': 'Ectodermal Neuronal Neuroectodermal Radialglialike',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Mesenchymal Facial Neural Crest',
#    'abbreviation': 'MesNC',
#    'definition': '+Lhx8 +Twist2 +Prrx1 +Dlx2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal NeuralCrest Face',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Hindbrain Excitatory type 3',
#    'abbreviation': 'HinEx3',
#    'definition': '+Tshz3 +Lhx2 +Foxb1 +Synpr',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Developmental Interneuron midbrain type 1',
#    'abbreviation': 'IntMid1',
#    'definition': '+Npy +Kiz +Six3 +Nxph1 -Nhlh2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Upper layer neurons',
#    'abbreviation': 'LUpper',
#    'definition': '+Satb2 +Rbfox1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Radialglia-like 1 Hindbrain',
#    'abbreviation': 'RglH1',
#    'definition': '+Ednrb +Wnt7b +Fgfr3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Developmental Interneuron forebrain ventral type 1',
#    'abbreviation': 'IntFV1',
#    'definition': '+Lhx8 +Adarb2 +Lhx6 +Nkx2-1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Entorhinal cortex',
#    'abbreviation': 'ERCx',
#    'definition': '+Chodl +Fam19a1 +Nefl +Nefm',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Midbrain floor plate',
#    'abbreviation': 'mFP',
#    'definition': '+Shh +Foxa1 +Foxa2 +Lmx1a +Lmx1b',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Forebrain Radialglia-like 2',
#    'abbreviation': 'RglF2',
#    'definition': '+Tnc +Ednrb +Bcan +Aldoc',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Radialglia 1 of the Hindbrain',
#    'abbreviation': 'HRgl1',
#    'definition': '+Msx3 +Pax3 +Id3 +Fgf15',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Hindbrain Spinal Dorsal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'D1 medium spiny neurons, striatum',
#    'abbreviation': 'MSN1',
#    'definition': '+Six3 +Sstr2 +Tle4 +Calb1 -Adora2a',
#    'related': 'NbMSN1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Radialglia Forebrain',
#    'abbreviation': 'RglFb',
#    'definition': '+Trip6 +Hes1 +Vim -Kdr -Rgs5 -Utf1 -Cldn4 -Mpz',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Hindbrain Excitatory type 4',
#    'abbreviation': 'HinEx4',
#    'definition': '+Lhx9 +Syt13 +Gng8 +C1ql3',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Dentate gyrus cells',
#    'abbreviation': 'HC-DGC',
#    'definition': '+Prox1 +Calb2 +Rerg +Lhx9',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Ependymocyte',
#    'abbreviation': 'EPN-Ep',
#    'definition': '+Sox2 +Vim +Tmem212 +Ccdc153',
#    'categories': 'Ectodermal Neuroectodermal'}],
#  [{'name': 'Orofacial Primordia',
#    'abbreviation': 'EcFace',
#    'definition': '+Sostdc1 +Perp -Tbx1 -Ttr',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Face',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Schwann cell like',
#    'abbreviation': 'SchLike',
#    'definition': '+Plp1 +Sox10 +Mbp +Mpz -Mog',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Astrocytes Type 1',
#    'abbreviation': 'Astro1',
#    'definition': '-Slc7a10 -Foxj1 +Gfap +Serpinf1',
#    'categories': 'Ectodermal Neuroectodermal'}],
#  [{'name': 'Thalamus 2',
#    'abbreviation': 'Th2',
#    'definition': '+Calb2 +Gbx2 +Id4 +Ldb2 -Ccnd2',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Ventromedial hypothalamus',
#    'abbreviation': 'Hypo-VM',
#    'definition': '+Sox14 +Fezf1 +Plp1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Thalamus 3',
#    'abbreviation': 'Th3',
#    'definition': '+Calb2 +Gbx2 +Id4 +Ldb2 +Ccnd2',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Early forebrain progentiors type 1',
#    'abbreviation': 'EFrPr1',
#    'definition': '+Nsg2 +Nkx2-9 +Ptch1 -Robo3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Forebrain Ectodermal Neuronal Neuroectodermal Radialglialike',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Interneurons from MGE',
#    'abbreviation': 'MGEInt',
#    'definition': '+Lhx6 +Ackr3 +Dlx1 +Dlx2 +Dlx5',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': None,
#    'synonyms': None}],
#  [{'name': 'Ventrolateral thalamus',
#    'abbreviation': 'VLThal',
#    'definition': '+Pitx2 +Adcyap1 +Vsnl1 +Calb2',
#    'categories': 'Ectodermal Neuroectodermal Neuronal'}],
#  [{'name': 'Optic Cup',
#    'abbreviation': 'OptC',
#    'definition': '+Trpm1 +Vax2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Epiblast pluripotent stem cells',
#    'abbreviation': 'PSC',
#    'definition': '+Fgf5 +Pou5f1 +Utf1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Endomesodermal',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Hindbrain Excitatory type 5',
#    'abbreviation': 'HinEx5',
#    'definition': '+Pou4f1 +Hmx2 +Pou4f2 +Hmx3 +Foxp2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Tectal gray formation Neuroblast type 3a',
#    'abbreviation': 'NbTG3a',
#    'definition': '+Tfap2b +Sncg +Isl1 +Isl2 +Tlx3',
#    'related': 'NbTG1 NbTG NbTG2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Midbrain type 7',
#    'abbreviation': 'NbMid7',
#    'definition': '+Neurod2 +Nxph4 +Ebf2 +Neurod6 +Glra2',
#    'related': '@CHind Glyc-Skor1 CB-MLI',
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Reticular Complex Neuroblasts',
#    'abbreviation': 'NbRtC',
#    'definition': '+Six3 +Pax6 +Isl1 +Fign +Meis2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Tectal gray formation Gabaergic Neuroblast type 2',
#    'abbreviation': 'NbIntTG2',
#    'definition': '+Tfap2b +Nxph1 +Fstl4 -Foxp2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Midbrain type 11',
#    'abbreviation': 'NbMid11',
#    'definition': '+Fibcd1 +Grm3 +Irx2 +Irx1',
#    'related': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Forebrain neuroblast type 4',
#    'abbreviation': 'NbFor4',
#    'definition': '+Lmo3 +Grm5 +Runx1t1 +Nrp2 -Syn3',
#    'related': 'NbFor9',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Neuroblast Hindrain 1',
#    'abbreviation': 'NbHin1',
#    'definition': '+Tfap2d +Fzd1 +Cnpy1 +Lhx2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Basal Ganglia Neuroblast 1',
#    'abbreviation': 'NbBg1',
#    'definition': '+Meis1 +Meis2 +Cck',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Tectal gray formation Neuroblast type 1',
#    'abbreviation': 'NbTG1',
#    'definition': '+Tfap2b +Neurod4 +Neurog2 +Otx2os1',
#    'related': 'NbTG1 NbTG',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast glutamatergic, maybe DH sensory',
#    'abbreviation': 'NbGlutDH',
#    'definition': '+Tlx3 +Prrxl1 +Lmx1b +Slc17a6',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Midbrain 1',
#    'abbreviation': 'NbMid1',
#    'definition': '+Pcsk9 +Neurod2 +Mfap4 +Nrg1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Pallidum or POA Neuroblasts',
#    'abbreviation': 'NbPal',
#    'definition': '+Gsx1 +Ascl1 +Pon2 +Isl1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Hindbrain C1 Glutamatergic Neuroblast',
#    'abbreviation': 'NbGlutHc1',
#    'definition': '+Lhx2 +Lhx9 +Atoh1 +Barhl2 +Barhl1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Gabaergic Neuroblast of the colliculus',
#    'abbreviation': 'NbIntCL1',
#    'definition': '+Pdzd2 +Trpm3 +Col25a1 +Pax7 -Tcf7l2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Midbrain 2',
#    'abbreviation': 'NbMid2',
#    'definition': '+Ndst4 +Tfap2d +Grm5 +Cntn4 +Hs3st4',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Lateral 1',
#    'abbreviation': 'NblastL1',
#    'definition': '+Crabp1 +Onecut2 +Pitx2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Tectal gray formation Neuroblast type 2',
#    'abbreviation': 'NbTG2',
#    'definition': '+Tfap2b +Pcp4 +Foxb1 +Bcl11a',
#    'related': 'NbTG1 NbTG',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Hindbrain type 3',
#    'abbreviation': 'NbHin3',
#    'definition': '+Phox2b +Pcp4 +Phox2a +Tlx3 +Shox2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Forebrain neuroblast type 6',
#    'abbreviation': 'NbFor6',
#    'definition': '+Tfap2d +Sstr2 +Sema3c +Neurod6 +Tbr1 -Tfap2e',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Tectal gray formation Gabaergic Neuroblast type 1',
#    'abbreviation': 'NbIntTG1',
#    'definition': '+Tfap2b +Nxph1 +Foxp2 +Ptprk -Fstl4',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Hindrain 2',
#    'abbreviation': 'NbHin2',
#    'definition': '+Syt13 +C1ql3 +Nr4a2',
#    'related': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Midbrain 3',
#    'abbreviation': 'NbMid3',
#    'definition': '+Lmo3 +Islr2 +Neurod6 -C1ql2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast hindbrain V2b interneurons',
#    'abbreviation': 'NbIntV2b',
#    'definition': '+Gata3 +Gata2 +Tal1 +Sox14 +Otx1 -Shox2 -Tcf7l2',
#    'related': 'NbExcV2 NbIntV2a',
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Hindbrain type 5',
#    'abbreviation': 'NbHin5',
#    'definition': '+Lmx1a +Tfap2b +Irx3 +Mast4',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Neuroblast Midbrain type 8',
#    'abbreviation': 'NbMid8',
#    'definition': '+Nr4a2 +Tcf7l2 +Cbln2 +Grin3a',
#    'related': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Striatal Neuroblasts',
#    'abbreviation': 'NbMSN',
#    'definition': '+Ebf1 +Rarb +Rxrg',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Neuroblast Hindbrain gabaergic type 8',
#    'abbreviation': 'NbHind8',
#    'definition': '+Lypd1 +Wnt7b +Vstm2b',
#    'related': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal Neuroblast',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Tectal gray formation Neuroblast type 3b',
#    'abbreviation': 'NbTG3b',
#    'definition': '+Tfap2b +Sncg +Mmd2 +Klhl1 -Isl1',
#    'related': 'NbTG1 NbTG NbTG2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Medial',
#    'abbreviation': 'NblastM',
#    'definition': '+Neurod1 +Igfbpl1 +Stmn2 -Gfap',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Neuroblast Hindbrain type 4',
#    'abbreviation': 'NbHin4',
#    'definition': '+Tlx1 +Lbx1 +Kazald1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Neuroblast Forebrain 1',
#    'abbreviation': 'NbFor1',
#    'definition': '+Ebf2 +Uncx +Tbr1 +Aff3 +Nhlh2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Anterior Visceral Endoderm',
#    'abbreviation': 'AVE',
#    'definition': '+Cer1 +Hhex +Lefty1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Embryonic Definitive Endoderm',
#    'abbreviation': 'EDEndo',
#    'definition': '+Foxa2 +Sox17 +Cldn6',
#    'go': None,
#    'shogoin': None,
#    'uberon': '(outer molecular layer)',
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Distal Visceral Endoderm derived cells',
#    'abbreviation': 'DVE',
#    'definition': '+Cer1 +Hhex -Lefty1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Early Foregut cells',
#    'abbreviation': 'FGut',
#    'definition': '+Pyy +Apela',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Osteochondro mesenchymal cells',
#    'abbreviation': 'OstCho',
#    'definition': '+Steap1 +Postn',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Frontonasal Mesenchyme',
#    'abbreviation': 'FrontM',
#    'definition': '+Alx1 +Alx3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal Face',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Cardiac Crescent cells',
#    'abbreviation': 'CrCr',
#    'definition': '+Hand1 +Wnt2 +Hand2 -Wnt6 -Tacstd2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Erythroid lineage progenitors',
#    'abbreviation': 'Eryp',
#    'definition': '+Hbb-bh1 +Cited4 +Gfi1b +Klf1 -Tspo2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Cardiac Progenitor',
#    'abbreviation': 'CrPr',
#    'definition': '+Hand1 +Wnt6 +Tacstd2 -Wnt2 -Hand2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Angioblast',
#    'abbreviation': 'Angio',
#    'definition': '+Plvap +Kcne3 -Slc38a5 -Ly6a',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Dermomyotome',
#    'abbreviation': 'Dermo',
#    'definition': '+Twist2 +Tbx1 -Meox1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Anterior Early Mesodermal cells',
#    'abbreviation': 'AEMeso',
#    'definition': '+T +Noto',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Lateral Plate Mesoderm',
#    'abbreviation': 'LPMeso',
#    'definition': '+Mesp1 +Lefty2 +Mixl1 -Nodal',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Platelets',
#    'abbreviation': 'Plat',
#    'definition': '+Treml1 +Pf4 +Gp9 +Gp5',
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Paraxial Mesoderm',
#    'abbreviation': 'PxMeso',
#    'definition': '+Tcf15 +Meox1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Endomesodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Interneuron, hippocampus',
#    'abbreviation': 'HC-Ntng1-Chrm2',
#    'definition': '+Gad1 +Ntng1 +Chrm2',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Purkinje cell',
#    'abbreviation': 'CB-PC',
#    'definition': '+Pcp2 +Itpr1',
#    'categories': 'Ectodermal Neuronal Neuroectodermal'}],
#  [{'name': 'Peripheral Sensory Neuron',
#    'abbreviation': 'PSN',
#    'definition': '+Prph +Pirt',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal  NeuralCrest',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Putative septal neurons',
#    'abbreviation': 'SEPTAL',
#    'definition': '+Eomes +Slc6a7',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Cranial Motorneurons',
#    'abbreviation': 'CrMN',
#    'definition': '+Isl1 +Prph +Phox2a -Lhx3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Visceromotor Motorneurons',
#    'abbreviation': 'VscMN',
#    'definition': '+Tbx20 +Isl1 +Phox2a -Lhx3',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Pyramidal cell, hippocampus CA2',
#    'abbreviation': 'HC-CA2',
#    'definition': '+Zbtb20 +Rgs14',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Cajal-Retzius cell',
#    'abbreviation': 'CRC',
#    'definition': '+Reln +Trp73 +Lhx5 -Slc32a1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Nociceptor neuron',
#    'abbreviation': 'Noci',
#    'definition': '+Hoxd1 +Runx1 +Ntrk1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal NeuralCrest Neuronal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Spinal Motorneurons',
#    'abbreviation': 'SpMN',
#    'definition': '+Isl1 +Sst +Tlx2 +Shox2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Cranial Nerve',
#    'abbreviation': 'CrNerv',
#    'definition': '+Sall1 +Pou6f2',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 2,
#    'synonyms': None}],
#  [{'name': 'Granule cell, dentate gyrus',
#    'abbreviation': 'DG-GC',
#    'definition': '+C1ql2 +Prox1 -Sv2b',
#    'go': None,
#    'shogoin': None,
#    'uberon': '(granule layer)',
#    'categories': 'Ectodermal Neuronal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Ependymal',
#    'abbreviation': 'EPN',
#    'definition': '+Ccdc153 +Tmem212',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Committed oligodendrocyte precursor cell',
#    'abbreviation': 'COP',
#    'definition': '+Bmp4 +Enpp6 +Gpr17',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': 'OPC',
#    'successors': 'NFOL'}],
#  [{'name': 'Astrocytes, non-forebrain',
#    'abbreviation': 'AC-NFB',
#    'definition': '+Slc1a2 +Scg3 +Agt',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}],
#  [{'name': 'Choriod Plexus',
#    'abbreviation': 'CHRD',
#    'definition': '+Ttr +Kcne2 +Aqp1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Subcommissural organ hypendymal cell',
#    'abbreviation': 'SCO-HYP',
#    'definition': '+Spdef +Ferd3l +Sspo',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike Glial',
#    'version': 1.5,
#    'synonyms': None}],
#  [{'name': 'Olfactory ensheathing cell',
#    'abbreviation': 'OB-OEC',
#    'definition': '+Npy +Plp1 +Ccdc80',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': 1,
#    'synonyms': None}],
#  [{'name': 'Oligodendrocyte precursor cell',
#    'abbreviation': 'OPC',
#    'definition': '+Pdgfra +Cspg4 -Lum',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal Radialglialike',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None,
#    'successors': 'OL-COP'}],
#  [{'name': 'Astroependymal',
#    'abbreviation': '@AEP',
#    'definition': '+Aqp4 +Gja1',
#    'go': None,
#    'shogoin': None,
#    'uberon': None,
#    'categories': 'Ectodermal Neuroectodermal',
#    'version': 1,
#    'synonyms': None,
#    'predecessors': None}]]

# %%
len(database)
# Out:
# 215

# %% [markdown]
# # Load the table with most expressed genes

# %%
table=pd.read_csv('~/Desktop/test.csv')

# %%
table
# Out:
#         0        1       2       3        4        5       6       7        8  \
# 0    Gkn3   Tcf7l2    Otx2  Tfap2b  Gm17750  Igfbpl1   Sox14  Tmsb10  Six3os1
# 1  Snhg11     Lhx9    Lmo1  Malat1     Ebf1     Lhx2    Nfib  Mllt11     Pnoc
# 2    Rtn1  Igfbpl1   H3f3b   Nxph1     Lef1    Rps11    Lhx5  Tuba1a     Six3
# 3     Ndn    Tubb5  Adarb2    Gad2     Lmo3   Rpl13a  Tfap2b   Gap43      Npy
# 4    Ly6h    Sox11  Malat1   Nrxn3    Islr2     Rps6    Gad2    Nnat     Uncx
#
#        9        10      11      12        13
# 0    Vim     Sparc   Alas2    C1qc     Kcnj8
# 1  Fabp7       Vim  Hbb-bs    C1qa      Rgs5
# 2  Phgdh     Itm2a  Hbb-bt   Trem2      Mmp9
# 3    Ckb  Serpinh1  Hba-a2  Cx3cr1  Ndufa4l2
# 4  Plpp3     Rps27  Hba-a1    Pld4     Cald1

# %% [markdown]
# # Function for annotation

# %%
def annotation_helper(table, database):
    
    # Number of clusters
    number_of_clusters = len(table.columns)

    # Create a table to display results
    result_all = pd.DataFrame()

    for cluster_id in range(number_of_clusters):

        # Collecting list of genes for 'cluster_id' as array
        genes_list = table.iloc[:,cluster_id].values
        genes_number = len(genes_list)

        # Creating a list for search results
        result_cluster = [''] * genes_number
        print('')
        print('Working on cluster: ', cluster_id)
        print('List of genes: '     , genes_list)
        print('Number of genes: '   , genes_number)

        # Search each gene from 'genes_list' in database
        for x in range(len(database)):
            for i in range(genes_number):  

                if '+{}'.format(genes_list[i]) in database[x][0]['definition']:
                    result_cluster[i] += '+{}\n'.format(database[x][0]['abbreviation'])
                    print('Found {} as a + marker for {}'.format(genes_list[i],database[x][0]['name']))

                elif '-{}'.format(genes_list[i]) in database[x][0]['definition']:
                    result_cluster[i] += '-{}\n'.format(database[x][0]['abbreviation'])
                    print('Found {} as a - marker for {}'.format(genes_list[i],database[x][0]['name']))
        
        #print(result_cluster)

        # Write result
        result_all = pd.concat([result_all, pd.DataFrame({'cluster_{}'.format(cluster_id):genes_list, 'result_{}'.format(cluster_id):result_cluster})], axis=1)
    
    return result_all

# %%
result_all = annotation_helper(table, database)
# Out:
# Working on cluster:  0
# List of genes:  ['Gkn3' 'Snhg11' 'Rtn1' 'Ndn' 'Ly6h']
# Number of genes:  5
# Found Gkn3 as a + marker for Angiogenesis activation
#
# Working on cluster:  1
# List of genes:  ['Tcf7l2' 'Lhx9' 'Igfbpl1' 'Tubb5' 'Sox11']
# Number of genes:  5
# Found Tcf7l2 as a + marker for Roof plate of Thalamus
# Found Tcf7l2 as a + marker for Epithalamus
# Found Igfbpl1 as a + marker for Neural Progenitors
# Found Tcf7l2 as a - marker for Neuron hindbrain V2b interneurons
# Found Tcf7l2 as a + marker for Dorsal Thalamic tier Excitatory type 1
# Found Lhx9 as a + marker for Hindbrain Excitatory type 4
# Found Lhx9 as a + marker for Dentate gyrus cells
# Found Lhx9 as a + marker for Hindbrain C1 Glutamatergic Neuroblast
# Found Tcf7l2 as a - marker for Gabaergic Neuroblast of the colliculus
# Found Tcf7l2 as a - marker for Neuroblast hindbrain V2b interneurons
# Found Tcf7l2 as a + marker for Neuroblast Midbrain type 8
# Found Igfbpl1 as a + marker for Neuroblast Medial
#
# Working on cluster:  2
# List of genes:  ['Otx2' 'Lmo1' 'H3f3b' 'Adarb2' 'Malat1']
# Number of genes:  5
# Found Otx2 as a - marker for Posterior Neural Tube
# Found Otx2 as a + marker for Midbrain-Hindbrain boundary rostral
# Found Otx2 as a - marker for Midbrain-Hindbrain boundary caudal
# Found Adarb2 as a + marker for Interneurons from CGE
# Found Adarb2 as a + marker for Gabaergic neurons cerebellar c2v
# Found Adarb2 as a + marker for Developmental Interneuron forebrain ventral type 1
# Found Otx2 as a + marker for Tectal gray formation Neuroblast type 1
#
# Working on cluster:  3
# List of genes:  ['Tfap2b' 'Malat1' 'Nxph1' 'Gad2' 'Nrxn3']
# Number of genes:  5
# Found Gad2 as a + marker for GABAergic and Glutamatergic VGLUT1
# Found Gad2 as a + marker for GABAergic
# Found Nrxn3 as a + marker for Glycinergic neurons expressing Skor1
# Found Nxph1 as a + marker for Developmental Interneuron hippocampus-like type 1
# Found Nrxn3 as a + marker for Developmental Interneuron hippocampus-like type 1
# Found Gad2 as a + marker for Gabaergic neurons cerebellar c2v
# Found Nxph1 as a + marker for Developmental Interneuron midbrain type 1
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3a
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 2
# Found Nxph1 as a + marker for Tectal gray formation Gabaergic Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 1
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 1
# Found Nxph1 as a + marker for Tectal gray formation Gabaergic Neuroblast type 1
# Found Tfap2b as a + marker for Neuroblast Hindbrain type 5
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3b
#
# Working on cluster:  4
# List of genes:  ['Gm17750' 'Ebf1' 'Lef1' 'Lmo3' 'Islr2']
# Number of genes:  5
# Found Islr2 as a + marker for Developmental Interneuron hindbrain type 1
# Found Lmo3 as a + marker for Forebrain neuroblast type 4
# Found Lmo3 as a + marker for Neuroblast Midbrain 3
# Found Islr2 as a + marker for Neuroblast Midbrain 3
# Found Ebf1 as a + marker for Striatal Neuroblasts
#
# Working on cluster:  5
# List of genes:  ['Igfbpl1' 'Lhx2' 'Rps11' 'Rpl13a' 'Rps6']
# Number of genes:  5
# Found Lhx2 as a + marker for Oxytocin
# Found Lhx2 as a + marker for Eye Field cells
# Found Igfbpl1 as a + marker for Neural Progenitors
# Found Lhx2 as a + marker for Hindbrain Excitatory type 3
# Found Lhx2 as a + marker for Neuroblast Hindrain 1
# Found Lhx2 as a + marker for Hindbrain C1 Glutamatergic Neuroblast
# Found Igfbpl1 as a + marker for Neuroblast Medial
#
# Working on cluster:  6
# List of genes:  ['Sox14' 'Nfib' 'Lhx5' 'Tfap2b' 'Gad2']
# Number of genes:  5
# Found Gad2 as a + marker for GABAergic and Glutamatergic VGLUT1
# Found Gad2 as a + marker for GABAergic
# Found Sox14 as a + marker for Dorsal (rostral) Midbrain and other regions
# Found Lhx5 as a + marker for Cortical Hem
# Found Nfib as a + marker for Developmental Interneuron midbrain type 2
# Found Sox14 as a + marker for Neuron hindbrain V2b interneurons
# Found Gad2 as a + marker for Gabaergic neurons cerebellar c2v
# Found Sox14 as a + marker for Ventromedial hypothalamus
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3a
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 1
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 1
# Found Sox14 as a + marker for Neuroblast hindbrain V2b interneurons
# Found Tfap2b as a + marker for Neuroblast Hindbrain type 5
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3b
# Found Lhx5 as a + marker for Cajal-Retzius cell
#
# Working on cluster:  7
# List of genes:  ['Tmsb10' 'Mllt11' 'Tuba1a' 'Gap43' 'Nnat']
# Number of genes:  5
#
# Working on cluster:  8
# List of genes:  ['Six3os1' 'Pnoc' 'Six3' 'Npy' 'Uncx']
# Number of genes:  5
# Found Npy as a + marker for Agouti-related peptide
# Found Six3 as a + marker for Eye Field cells
# Found Npy as a - marker for Developmental Interneuron midbrain type 2
# Found Six3 as a - marker for Midbrain Inhibitory Progenitors
# Found Six3 as a + marker for Anterior NeuroEctoderm
# Found Uncx as a + marker for Mammillary region of the hypothalamus
# Found Six3 as a + marker for Developmental Interneuron midbrain type 1
# Found Npy as a + marker for Developmental Interneuron midbrain type 1
# Found Six3 as a + marker for D1 medium spiny neurons, striatum
# Found Six3 as a + marker for Reticular Complex Neuroblasts
# Found Uncx as a + marker for Neuroblast Forebrain 1
# Found Npy as a + marker for Olfactory ensheathing cell
#
# Working on cluster:  9
# List of genes:  ['Vim' 'Fabp7' 'Phgdh' 'Ckb' 'Plpp3']
# Number of genes:  5
# Found Vim as a + marker for Radialglia Midbrain Hindbrain
# Found Vim as a + marker for Tanycyte
# Found Vim as a + marker for Radialglia
# Found Vim as a + marker for Radialglia Forebrain
# Found Vim as a + marker for Ependymocyte
#
# Working on cluster:  10
# List of genes:  ['Sparc' 'Vim' 'Itm2a' 'Serpinh1' 'Rps27']
# Number of genes:  5
# Found Vim as a + marker for Radialglia Midbrain Hindbrain
# Found Vim as a + marker for Tanycyte
# Found Vim as a + marker for Radialglia
# Found Vim as a + marker for Radialglia Forebrain
# Found Vim as a + marker for Ependymocyte
#
# Working on cluster:  11
# List of genes:  ['Alas2' 'Hbb-bs' 'Hbb-bt' 'Hba-a2' 'Hba-a1']
# Number of genes:  5
# Found Alas2 as a + marker for Erythrocyte
# Found Hba-a2 as a + marker for Erythrocyte
#
# Working on cluster:  12
# List of genes:  ['C1qc' 'C1qa' 'Trem2' 'Cx3cr1' 'Pld4']
# Number of genes:  5
#
# Working on cluster:  13
# List of genes:  ['Kcnj8' 'Rgs5' 'Mmp9' 'Ndufa4l2' 'Cald1']
# Number of genes:  5
# Found Rgs5 as a + marker for Pericyte
# Found Rgs5 as a - marker for Radialglia Midbrain Hindbrain
# Found Rgs5 as a - marker for Radialglia
# Found Rgs5 as a - marker for Radialglia Forebrain

# %%
def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )

# %%
pretty_print(result_all)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster_0</th>
#       <th>result_0</th>
#       <th>cluster_1</th>
#       <th>result_1</th>
#       <th>cluster_2</th>
#       <th>result_2</th>
#       <th>cluster_3</th>
#       <th>result_3</th>
#       <th>cluster_4</th>
#       <th>result_4</th>
#       <th>cluster_5</th>
#       <th>result_5</th>
#       <th>cluster_6</th>
#       <th>result_6</th>
#       <th>cluster_7</th>
#       <th>result_7</th>
#       <th>cluster_8</th>
#       <th>result_8</th>
#       <th>cluster_9</th>
#       <th>result_9</th>
#       <th>cluster_10</th>
#       <th>result_10</th>
#       <th>cluster_11</th>
#       <th>result_11</th>
#       <th>cluster_12</th>
#       <th>result_12</th>
#       <th>cluster_13</th>
#       <th>result_13</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Gkn3</td>
#       <td>+@Angio<br></td>
#       <td>Tcf7l2</td>
#       <td>+@p2RP<br>+epiTh<br>-IntV2b<br>+ThaEx1<br>-NbIntCL1<br>-NbIntV2b<br>+NbMid8<br></td>
#       <td>Otx2</td>
#       <td>-@PNT<br>+@MHBr<br>-@MHBc<br>+NbTG1<br></td>
#       <td>Tfap2b</td>
#       <td>+NbTG3a<br>+NbIntTG2<br>+NbTG1<br>+NbTG2<br>+NbIntTG1<br>+NbHin5<br>+NbTG3b<br></td>
#       <td>Gm17750</td>
#       <td></td>
#       <td>Igfbpl1</td>
#       <td>+NProg<br>+NblastM<br></td>
#       <td>Sox14</td>
#       <td>+@DMid<br>+IntV2b<br>+Hypo-VM<br>+NbIntV2b<br></td>
#       <td>Tmsb10</td>
#       <td></td>
#       <td>Six3os1</td>
#       <td></td>
#       <td>Vim</td>
#       <td>+RglMHb<br>+EPN-T<br>+Rgl<br>+RglFb<br>+EPN-Ep<br></td>
#       <td>Sparc</td>
#       <td></td>
#       <td>Alas2</td>
#       <td>+ERY<br></td>
#       <td>C1qc</td>
#       <td></td>
#       <td>Kcnj8</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Snhg11</td>
#       <td></td>
#       <td>Lhx9</td>
#       <td>+HinEx4<br>+HC-DGC<br>+NbGlutHc1<br></td>
#       <td>Lmo1</td>
#       <td></td>
#       <td>Malat1</td>
#       <td></td>
#       <td>Ebf1</td>
#       <td>+NbMSN<br></td>
#       <td>Lhx2</td>
#       <td>+@OXT<br>+@Eye<br>+HinEx3<br>+NbHin1<br>+NbGlutHc1<br></td>
#       <td>Nfib</td>
#       <td>+IntMid2<br></td>
#       <td>Mllt11</td>
#       <td></td>
#       <td>Pnoc</td>
#       <td></td>
#       <td>Fabp7</td>
#       <td></td>
#       <td>Vim</td>
#       <td>+RglMHb<br>+EPN-T<br>+Rgl<br>+RglFb<br>+EPN-Ep<br></td>
#       <td>Hbb-bs</td>
#       <td></td>
#       <td>C1qa</td>
#       <td></td>
#       <td>Rgs5</td>
#       <td>+PERI<br>-RglMHb<br>-Rgl<br>-RglFb<br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Rtn1</td>
#       <td></td>
#       <td>Igfbpl1</td>
#       <td>+NProg<br>+NblastM<br></td>
#       <td>H3f3b</td>
#       <td></td>
#       <td>Nxph1</td>
#       <td>+IntHc1<br>+IntMid1<br>+NbIntTG2<br>+NbIntTG1<br></td>
#       <td>Lef1</td>
#       <td></td>
#       <td>Rps11</td>
#       <td></td>
#       <td>Lhx5</td>
#       <td>+@Hem<br>+CRC<br></td>
#       <td>Tuba1a</td>
#       <td></td>
#       <td>Six3</td>
#       <td>+@Eye<br>-MGabaProg<br>+ANE<br>+IntMid1<br>+MSN1<br>+NbRtC<br></td>
#       <td>Phgdh</td>
#       <td></td>
#       <td>Itm2a</td>
#       <td></td>
#       <td>Hbb-bt</td>
#       <td></td>
#       <td>Trem2</td>
#       <td></td>
#       <td>Mmp9</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Ndn</td>
#       <td></td>
#       <td>Tubb5</td>
#       <td></td>
#       <td>Adarb2</td>
#       <td>+CGEInt<br>+Glyc-Cblc2<br>+IntFV1<br></td>
#       <td>Gad2</td>
#       <td>+@GABAGLUT1<br>+@GABA<br>+Glyc-Cblc2<br></td>
#       <td>Lmo3</td>
#       <td>+NbFor4<br>+NbMid3<br></td>
#       <td>Rpl13a</td>
#       <td></td>
#       <td>Tfap2b</td>
#       <td>+NbTG3a<br>+NbIntTG2<br>+NbTG1<br>+NbTG2<br>+NbIntTG1<br>+NbHin5<br>+NbTG3b<br></td>
#       <td>Gap43</td>
#       <td></td>
#       <td>Npy</td>
#       <td>+@AGRP<br>-IntMid2<br>+IntMid1<br>+OB-OEC<br></td>
#       <td>Ckb</td>
#       <td></td>
#       <td>Serpinh1</td>
#       <td></td>
#       <td>Hba-a2</td>
#       <td>+ERY<br></td>
#       <td>Cx3cr1</td>
#       <td></td>
#       <td>Ndufa4l2</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Ly6h</td>
#       <td></td>
#       <td>Sox11</td>
#       <td></td>
#       <td>Malat1</td>
#       <td></td>
#       <td>Nrxn3</td>
#       <td>+Glyc-Skor1<br>+IntHc1<br></td>
#       <td>Islr2</td>
#       <td>+IntHin1<br>+NbMid3<br></td>
#       <td>Rps6</td>
#       <td></td>
#       <td>Gad2</td>
#       <td>+@GABAGLUT1<br>+@GABA<br>+Glyc-Cblc2<br></td>
#       <td>Nnat</td>
#       <td></td>
#       <td>Uncx</td>
#       <td>+MB<br>+NbFor1<br></td>
#       <td>Plpp3</td>
#       <td></td>
#       <td>Rps27</td>
#       <td></td>
#       <td>Hba-a1</td>
#       <td></td>
#       <td>Pld4</td>
#       <td></td>
#       <td>Cald1</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
