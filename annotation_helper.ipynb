# %%
import os
import sys
import numpy as np
import pandas as pd
import scanpy as sc
import yaml
from IPython.display import display, HTML

# %%
# settings to display all columns + print result
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 1000)

# %% [markdown]
# # Generate the database

# %%
# Create place to store the database
database = []

# Specify walk_dir
walk_dir = 'auto-annotation-md'

# Counter check for .yaml file (should be 215)
n = 0

# Make walk_dir absolute
walk_dir = os.path.abspath(walk_dir)

print('walk_dir (absolute) = ' + walk_dir)

for root, subdirs, files in os.walk(walk_dir):
    list_file_path = os.path.join(root, 'my-directory-list.txt')
    with open(list_file_path, 'wb') as list_file:
        for filename in files:
            file_path = os.path.join(root, filename)
            
            with open(file_path, 'r') as stream:
                
                if file_path[-5:] == '.yaml':
                    
                    print('')
                    print(file_path)
                    n += 1
                    content = stream.read()
                    database.append(list(yaml.load_all(content.split("---", 1)[0])))
                    print(n)
# Out:
# walk_dir (absolute) = /Users/jrrrrr/Desktop/annotation/auto-annotation-md
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@VGLUT2.yaml
# 1
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@CHOL.yaml
# 2
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@VGLUT3.yaml
# 3
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@SER.yaml
# 4
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@ADR.yaml
# 5
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@NOR.yaml
# 6
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@Hr3r5.yaml
# 7
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@GABAGLUT1.yaml
# 8
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@GABA.yaml
# 9
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@Hr4.yaml
# 10
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@GLY.yaml
# 11
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@DA.yaml
# 12
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neurotransmission/@VGLUT1.yaml
# 13
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neuropeptides/@GNRH.yaml
# 14
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neuropeptides/@AVP.yaml
# 15
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neuropeptides/@OXT.yaml
# 16
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neuropeptides/@AGRP.yaml
# 17
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neuropeptides/@TRH.yaml
# 18
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neuropeptides/@HCRT.yaml
# 19
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Neuropeptides/@POMC.yaml
# 20
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Sex/@XIN.yaml
# 21
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Activation/@Cldn.yaml
# 22
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Activation/@EarlyNT.yaml
# 23
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Activation/@IEG.yaml
# 24
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Activation/@Angio.yaml
# 25
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@SpnlC.yaml
# 26
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@p2AL.yaml
# 27
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@MHBm.yaml
# 28
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@PNT.yaml
# 29
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@Cdx.yaml
# 30
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@NFold.yaml
# 31
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@Pall.yaml
# 32
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@p2RP.yaml
# 33
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@RDie.yaml
# 34
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@MHBr.yaml
# 35
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@CHind.yaml
# 36
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@HoxCaud.yaml
# 37
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@Hr2Sc.yaml
# 38
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@EDrCau.yaml
# 39
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@Habe.yaml
# 40
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@Dienc.yaml
# 41
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@Eye.yaml
# 42
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@pTh.yaml
# 43
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@PMid.yaml
# 44
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@MHBw.yaml
# 45
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@MHBc.yaml
# 46
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Patterning/@DMid.yaml
# 47
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Class/@Msn.yaml
# 48
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Class/@BMono.yaml
# 49
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Class/@CC.yaml
# 50
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Class/@OL.yaml
# 51
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Organizers/@CoP.yaml
# 52
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Organizers/RglMdOr.yaml
# 53
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Attribute/Organizers/@Hem.yaml
# 54
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/GUM.yaml
# 55
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/CARD.yaml
# 56
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Blood/PVM.yaml
# 57
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Blood/MGL.yaml
# 58
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Blood/ERY.yaml
# 59
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Blood/PLAT.yaml
# 60
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Vascular/VEC.yaml
# 61
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Vascular/VEC-FC.yaml
# 62
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Vascular/PERI.yaml
# 63
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Vascular/VSM.yaml
# 64
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Vascular/VLMC.yaml
# 65
# /Users/jrrrrr/miniconda3/envs/scanpy/lib/python3.6/site-packages/ipykernel_launcher.py:29: YAMLLoadWarning: calling yaml.load_all() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Mesodermal/Vascular/MFIB.yaml
# 66
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Extraembryonic/EHProg.yaml
# 67
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Extraembryonic/ExVE.yaml
# 68
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Extraembryonic/Tropho.yaml
# 69
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Glyc-Skor1.yaml
# 70
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/NProgCrbl.yaml
# 71
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Dlx.yaml
# 72
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Astro3.yaml
# 73
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/epiTh.yaml
# 74
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/CNC.yaml
# 75
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinSert.yaml
# 76
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Astro2.yaml
# 77
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/NProgH1.yaml
# 78
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Th1.yaml
# 79
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/RglM2.yaml
# 80
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Nose.yaml
# 81
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinNProg.yaml
# 82
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/VZone.yaml
# 83
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/CGEInt.yaml
# 84
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/mDA.yaml
# 85
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/RglMHb.yaml
# 86
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Hypo-L.yaml
# 87
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/eTEGLU.yaml
# 88
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/EPN-T.yaml
# 89
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HC-CA-Dev.yaml
# 90
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/TcCbProg.yaml
# 91
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/NProg.yaml
# 92
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/eHyPep.yaml
# 93
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/preTh.yaml
# 94
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/DelaNC.yaml
# 95
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/rAC.yaml
# 96
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/IntMid2.yaml
# 97
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/IntV2b.yaml
# 98
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Rgl2.yaml
# 99
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MSN4.yaml
# 100
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/IntHc1.yaml
# 101
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinEx1.yaml
# 102
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/ThaEx1.yaml
# 103
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/preTh2.yaml
# 104
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Glyc-Cblc2.yaml
# 105
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/OBNbl1.yaml
# 106
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinNC.yaml
# 107
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HRgl3.yaml
# 108
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/NIPC.yaml
# 109
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/NProgF.yaml
# 110
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MigPyr.yaml
# 111
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/LDeep.yaml
# 112
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MGabaProg.yaml
# 113
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Rgl2c.yaml
# 114
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/NProgML1.yaml
# 115
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/ANE.yaml
# 116
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/IntHin1.yaml
# 117
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MB.yaml
# 118
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Rgl.yaml
# 119
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinEx2.yaml
# 120
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/OBNbl2.yaml
# 121
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MRgl3.yaml
# 122
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MesNC.yaml
# 123
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinEx3.yaml
# 124
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/IntMid1.yaml
# 125
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/LUpper.yaml
# 126
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/RglH1.yaml
# 127
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/IntFV1.yaml
# 128
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/ERCx.yaml
# 129
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/mFP.yaml
# 130
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/RglF2.yaml
# 131
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HRgl1.yaml
# 132
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MSN1.yaml
# 133
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/RglFb.yaml
# 134
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinEx4.yaml
# 135
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HC-DGC.yaml
# 136
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/EPN-Ep.yaml
# 137
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/EcFace.yaml
# 138
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/SchLike.yaml
# 139
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Astro1.yaml
# 140
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Th2.yaml
# 141
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Hypo-VM.yaml
# 142
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Th3.yaml
# 143
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/EFrPr1.yaml
# 144
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/MGEInt.yaml
# 145
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/VLThal.yaml
# 146
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/OptC.yaml
# 147
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/PSC.yaml
# 148
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/HinEx5.yaml
# 149
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbTG3a.yaml
# 150
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbMid7.yaml
# 151
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbRtC.yaml
# 152
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbIntTG2.yaml
# 153
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbMid11.yaml
# 154
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbFor4.yaml
# 155
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbHin1.yaml
# 156
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbBg1.yaml
# 157
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbTG1.yaml
# 158
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbGlutDH.yaml
# 159
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbMid1.yaml
# 160
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbPal.yaml
# 161
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbGlutHc1.yaml
# 162
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbIntCL1.yaml
# 163
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbMid2.yaml
# 164
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NblastL1.yaml
# 165
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbTG2.yaml
# 166
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbHin3.yaml
# 167
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbFor6.yaml
# 168
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbIntTG1.yaml
# 169
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbHin2.yaml
# 170
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbMid3.yaml
# 171
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbIntV2b.yaml
# 172
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbHin5.yaml
# 173
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbMid8.yaml
# 174
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbMSN.yaml
# 175
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbHin8.yaml
# 176
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbTG3b.yaml
# 177
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NblastM.yaml
# 178
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbHin4.yaml
# 179
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Ectoderm/Neuroblasts/NbFor1.yaml
# 180
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Endoderm/AVE.yaml
# 181
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Endoderm/EDEndo.yaml
# 182
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Endoderm/DVE.yaml
# 183
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Endoderm/FGut.yaml
# 184
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/OstCho.yaml
# 185
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/FrontM.yaml
# 186
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/CrCr.yaml
# 187
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/Eryp.yaml
# 188
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/CrPr.yaml
# 189
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/Angio.yaml
# 190
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/Dermo.yaml
# 191
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/AEMeso.yaml
# 192
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/LPMeso.yaml
# 193
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/Plat.yaml
# 194
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Developmental/Mesoderm/PxMeso.yaml
# 195
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Inhibitory/HC-Ntng1-Chrm2.yaml
# 196
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Inhibitory/CB-PC.yaml
# 197
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Peripheral/PSN.yaml
# 198
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/SEPTAL.yaml
# 199
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/CrMN.yaml
# 200
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/VscMN.yaml
# 201
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/HC-CA2.yaml
# 202
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/CRC.yaml
# 203
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/Noci.yaml
# 204
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/SpMN.yaml
# 205
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/CrNerv.yaml
# 206
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Neuronal/Excitatory/DG-GC.yaml
# 207
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/EPN.yaml
# 208
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/COP.yaml
# 209
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/AC-NFB.yaml
# 210
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/CHRD.yaml
# 211
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/SCO-HYP.yaml
# 212
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/OB-OEC.yaml
# 213
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/OPC.yaml
# 214
#
# /Users/jrrrrr/Desktop/annotation/auto-annotation-md/Ectodermal/Neural/Glial/@AEP.yaml
# 215

# %%
len(database)
# Out:
# 215

# %% [markdown]
# # Load the table with most expressed genes

# %%
table=pd.read_csv('~/Desktop/test.csv')

# %%
table
# Out:
#         0        1       2       3        4        5       6       7        8  \
# 0    Gkn3   Tcf7l2    Otx2  Tfap2b  Gm17750  Igfbpl1   Sox14  Tmsb10  Six3os1
# 1  Snhg11     Lhx9    Lmo1  Malat1     Ebf1     Lhx2    Nfib  Mllt11     Pnoc
# 2    Rtn1  Igfbpl1   H3f3b   Nxph1     Lef1    Rps11    Lhx5  Tuba1a     Six3
# 3     Ndn    Tubb5  Adarb2    Gad2     Lmo3   Rpl13a  Tfap2b   Gap43      Npy
# 4    Ly6h    Sox11  Malat1   Nrxn3    Islr2     Rps6    Gad2    Nnat     Uncx
#
#        9        10      11      12        13
# 0    Vim     Sparc   Alas2    C1qc     Kcnj8
# 1  Fabp7       Vim  Hbb-bs    C1qa      Rgs5
# 2  Phgdh     Itm2a  Hbb-bt   Trem2      Mmp9
# 3    Ckb  Serpinh1  Hba-a2  Cx3cr1  Ndufa4l2
# 4  Plpp3     Rps27  Hba-a1    Pld4     Cald1

# %%
database[0]
# Out:
# [{'name': 'Glutamatergic 2',
#   'abbreviation': '@VGLUT2',
#   'definition': '+Slc17a6',
#   'go': None,
#   'shogoin': None,
#   'uberon': None,
#   'categories': 'Ectodermal Neuronal Neuroectodermal',
#   'version': 1,
#   'synonyms': ['Glutamatergic neurotransmission']}]

# %% [markdown]
# # Function for annotation

# %%
def annotation_helper(table, database):
    
    # Number of clusters
    number_of_clusters = len(table.columns)

    # Create a table to display results
    result_all = pd.DataFrame()

    for cluster_id in range(number_of_clusters):

        # Collecting list of genes for 'cluster_id' as array
        genes_list = table.iloc[:,cluster_id].values
        genes_number = len(genes_list)

        # Creating a list for search results
        result_cluster = [''] * genes_number
        print('')
        print('Working on cluster: ', cluster_id)
        print('List of genes: '     , genes_list)
        print('Number of genes: '   , genes_number)

        # Search each gene from 'genes_list' in database
        for x in range(len(database)):
            for i in range(genes_number):  

                if '+{}'.format(genes_list[i]) in database[x][0]['definition']:
                    result_cluster[i] += '+{}\n'.format(database[x][0]['abbreviation'])
                    print('Found {} as a + marker for {}'.format(genes_list[i],database[x][0]['name']))

                elif '-{}'.format(genes_list[i]) in database[x][0]['definition']:
                    result_cluster[i] += '-{}\n'.format(database[x][0]['abbreviation'])
                    print('Found {} as a - marker for {}'.format(genes_list[i],database[x][0]['name']))
        
        #print(result_cluster)

        # Write result
        result_all = pd.concat([result_all, pd.DataFrame({'cluster_{}'.format(cluster_id):genes_list, 'result_{}'.format(cluster_id):result_cluster})], axis=1)
    
    return result_all

# %%
result_all = annotation_helper(table, database)
# Out:
# Working on cluster:  0
# List of genes:  ['Gkn3' 'Snhg11' 'Rtn1' 'Ndn' 'Ly6h']
# Number of genes:  5
# Found Gkn3 as a + marker for Angiogenesis activation
#
# Working on cluster:  1
# List of genes:  ['Tcf7l2' 'Lhx9' 'Igfbpl1' 'Tubb5' 'Sox11']
# Number of genes:  5
# Found Tcf7l2 as a + marker for Roof plate of Thalamus
# Found Tcf7l2 as a + marker for Epithalamus
# Found Igfbpl1 as a + marker for Neural Progenitors
# Found Tcf7l2 as a - marker for Neuron hindbrain V2b interneurons
# Found Tcf7l2 as a + marker for Dorsal Thalamic tier Excitatory type 1
# Found Lhx9 as a + marker for Hindbrain Excitatory type 4
# Found Lhx9 as a + marker for Dentate gyrus cells
# Found Lhx9 as a + marker for Hindbrain C1 Glutamatergic Neuroblast
# Found Tcf7l2 as a - marker for Gabaergic Neuroblast of the colliculus
# Found Tcf7l2 as a - marker for Neuroblast hindbrain V2b interneurons
# Found Tcf7l2 as a + marker for Neuroblast Midbrain type 8
# Found Igfbpl1 as a + marker for Neuroblast Medial
#
# Working on cluster:  2
# List of genes:  ['Otx2' 'Lmo1' 'H3f3b' 'Adarb2' 'Malat1']
# Number of genes:  5
# Found Otx2 as a - marker for Posterior Neural Tube
# Found Otx2 as a + marker for Midbrain-Hindbrain boundary rostral
# Found Otx2 as a - marker for Midbrain-Hindbrain boundary caudal
# Found Adarb2 as a + marker for Interneurons from CGE
# Found Adarb2 as a + marker for Gabaergic neurons cerebellar c2v
# Found Adarb2 as a + marker for Developmental Interneuron forebrain ventral type 1
# Found Otx2 as a + marker for Tectal gray formation Neuroblast type 1
#
# Working on cluster:  3
# List of genes:  ['Tfap2b' 'Malat1' 'Nxph1' 'Gad2' 'Nrxn3']
# Number of genes:  5
# Found Gad2 as a + marker for GABAergic and Glutamatergic VGLUT1
# Found Gad2 as a + marker for GABAergic
# Found Nrxn3 as a + marker for Glycinergic neurons expressing Skor1
# Found Nxph1 as a + marker for Developmental Interneuron hippocampus-like type 1
# Found Nrxn3 as a + marker for Developmental Interneuron hippocampus-like type 1
# Found Gad2 as a + marker for Gabaergic neurons cerebellar c2v
# Found Nxph1 as a + marker for Developmental Interneuron midbrain type 1
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3a
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 2
# Found Nxph1 as a + marker for Tectal gray formation Gabaergic Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 1
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 1
# Found Nxph1 as a + marker for Tectal gray formation Gabaergic Neuroblast type 1
# Found Tfap2b as a + marker for Neuroblast Hindbrain type 5
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3b
#
# Working on cluster:  4
# List of genes:  ['Gm17750' 'Ebf1' 'Lef1' 'Lmo3' 'Islr2']
# Number of genes:  5
# Found Islr2 as a + marker for Developmental Interneuron hindbrain type 1
# Found Lmo3 as a + marker for Forebrain neuroblast type 4
# Found Lmo3 as a + marker for Neuroblast Midbrain 3
# Found Islr2 as a + marker for Neuroblast Midbrain 3
# Found Ebf1 as a + marker for Striatal Neuroblasts
#
# Working on cluster:  5
# List of genes:  ['Igfbpl1' 'Lhx2' 'Rps11' 'Rpl13a' 'Rps6']
# Number of genes:  5
# Found Lhx2 as a + marker for Oxytocin
# Found Lhx2 as a + marker for Eye Field cells
# Found Igfbpl1 as a + marker for Neural Progenitors
# Found Lhx2 as a + marker for Hindbrain Excitatory type 3
# Found Lhx2 as a + marker for Neuroblast Hindrain 1
# Found Lhx2 as a + marker for Hindbrain C1 Glutamatergic Neuroblast
# Found Igfbpl1 as a + marker for Neuroblast Medial
#
# Working on cluster:  6
# List of genes:  ['Sox14' 'Nfib' 'Lhx5' 'Tfap2b' 'Gad2']
# Number of genes:  5
# Found Gad2 as a + marker for GABAergic and Glutamatergic VGLUT1
# Found Gad2 as a + marker for GABAergic
# Found Sox14 as a + marker for Dorsal (rostral) Midbrain and other regions
# Found Lhx5 as a + marker for Cortical Hem
# Found Nfib as a + marker for Developmental Interneuron midbrain type 2
# Found Sox14 as a + marker for Neuron hindbrain V2b interneurons
# Found Gad2 as a + marker for Gabaergic neurons cerebellar c2v
# Found Sox14 as a + marker for Ventromedial hypothalamus
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3a
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 1
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 2
# Found Tfap2b as a + marker for Tectal gray formation Gabaergic Neuroblast type 1
# Found Sox14 as a + marker for Neuroblast hindbrain V2b interneurons
# Found Tfap2b as a + marker for Neuroblast Hindbrain type 5
# Found Tfap2b as a + marker for Tectal gray formation Neuroblast type 3b
# Found Lhx5 as a + marker for Cajal-Retzius cell
#
# Working on cluster:  7
# List of genes:  ['Tmsb10' 'Mllt11' 'Tuba1a' 'Gap43' 'Nnat']
# Number of genes:  5
#
# Working on cluster:  8
# List of genes:  ['Six3os1' 'Pnoc' 'Six3' 'Npy' 'Uncx']
# Number of genes:  5
# Found Npy as a + marker for Agouti-related peptide
# Found Six3 as a + marker for Eye Field cells
# Found Npy as a - marker for Developmental Interneuron midbrain type 2
# Found Six3 as a - marker for Midbrain Inhibitory Progenitors
# Found Six3 as a + marker for Anterior NeuroEctoderm
# Found Uncx as a + marker for Mammillary region of the hypothalamus
# Found Six3 as a + marker for Developmental Interneuron midbrain type 1
# Found Npy as a + marker for Developmental Interneuron midbrain type 1
# Found Six3 as a + marker for D1 medium spiny neurons, striatum
# Found Six3 as a + marker for Reticular Complex Neuroblasts
# Found Uncx as a + marker for Neuroblast Forebrain 1
# Found Npy as a + marker for Olfactory ensheathing cell
#
# Working on cluster:  9
# List of genes:  ['Vim' 'Fabp7' 'Phgdh' 'Ckb' 'Plpp3']
# Number of genes:  5
# Found Vim as a + marker for Radialglia Midbrain Hindbrain
# Found Vim as a + marker for Tanycyte
# Found Vim as a + marker for Radialglia
# Found Vim as a + marker for Radialglia Forebrain
# Found Vim as a + marker for Ependymocyte
#
# Working on cluster:  10
# List of genes:  ['Sparc' 'Vim' 'Itm2a' 'Serpinh1' 'Rps27']
# Number of genes:  5
# Found Vim as a + marker for Radialglia Midbrain Hindbrain
# Found Vim as a + marker for Tanycyte
# Found Vim as a + marker for Radialglia
# Found Vim as a + marker for Radialglia Forebrain
# Found Vim as a + marker for Ependymocyte
#
# Working on cluster:  11
# List of genes:  ['Alas2' 'Hbb-bs' 'Hbb-bt' 'Hba-a2' 'Hba-a1']
# Number of genes:  5
# Found Alas2 as a + marker for Erythrocyte
# Found Hba-a2 as a + marker for Erythrocyte
#
# Working on cluster:  12
# List of genes:  ['C1qc' 'C1qa' 'Trem2' 'Cx3cr1' 'Pld4']
# Number of genes:  5
#
# Working on cluster:  13
# List of genes:  ['Kcnj8' 'Rgs5' 'Mmp9' 'Ndufa4l2' 'Cald1']
# Number of genes:  5
# Found Rgs5 as a + marker for Pericyte
# Found Rgs5 as a - marker for Radialglia Midbrain Hindbrain
# Found Rgs5 as a - marker for Radialglia
# Found Rgs5 as a - marker for Radialglia Forebrain

# %%
def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )

# %%
pretty_print(result_all)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster_0</th>
#       <th>result_0</th>
#       <th>cluster_1</th>
#       <th>result_1</th>
#       <th>cluster_2</th>
#       <th>result_2</th>
#       <th>cluster_3</th>
#       <th>result_3</th>
#       <th>cluster_4</th>
#       <th>result_4</th>
#       <th>cluster_5</th>
#       <th>result_5</th>
#       <th>cluster_6</th>
#       <th>result_6</th>
#       <th>cluster_7</th>
#       <th>result_7</th>
#       <th>cluster_8</th>
#       <th>result_8</th>
#       <th>cluster_9</th>
#       <th>result_9</th>
#       <th>cluster_10</th>
#       <th>result_10</th>
#       <th>cluster_11</th>
#       <th>result_11</th>
#       <th>cluster_12</th>
#       <th>result_12</th>
#       <th>cluster_13</th>
#       <th>result_13</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Gkn3</td>
#       <td>+@Angio<br></td>
#       <td>Tcf7l2</td>
#       <td>+@p2RP<br>+epiTh<br>-IntV2b<br>+ThaEx1<br>-NbIntCL1<br>-NbIntV2b<br>+NbMid8<br></td>
#       <td>Otx2</td>
#       <td>-@PNT<br>+@MHBr<br>-@MHBc<br>+NbTG1<br></td>
#       <td>Tfap2b</td>
#       <td>+NbTG3a<br>+NbIntTG2<br>+NbTG1<br>+NbTG2<br>+NbIntTG1<br>+NbHin5<br>+NbTG3b<br></td>
#       <td>Gm17750</td>
#       <td></td>
#       <td>Igfbpl1</td>
#       <td>+NProg<br>+NblastM<br></td>
#       <td>Sox14</td>
#       <td>+@DMid<br>+IntV2b<br>+Hypo-VM<br>+NbIntV2b<br></td>
#       <td>Tmsb10</td>
#       <td></td>
#       <td>Six3os1</td>
#       <td></td>
#       <td>Vim</td>
#       <td>+RglMHb<br>+EPN-T<br>+Rgl<br>+RglFb<br>+EPN-Ep<br></td>
#       <td>Sparc</td>
#       <td></td>
#       <td>Alas2</td>
#       <td>+ERY<br></td>
#       <td>C1qc</td>
#       <td></td>
#       <td>Kcnj8</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Snhg11</td>
#       <td></td>
#       <td>Lhx9</td>
#       <td>+HinEx4<br>+HC-DGC<br>+NbGlutHc1<br></td>
#       <td>Lmo1</td>
#       <td></td>
#       <td>Malat1</td>
#       <td></td>
#       <td>Ebf1</td>
#       <td>+NbMSN<br></td>
#       <td>Lhx2</td>
#       <td>+@OXT<br>+@Eye<br>+HinEx3<br>+NbHin1<br>+NbGlutHc1<br></td>
#       <td>Nfib</td>
#       <td>+IntMid2<br></td>
#       <td>Mllt11</td>
#       <td></td>
#       <td>Pnoc</td>
#       <td></td>
#       <td>Fabp7</td>
#       <td></td>
#       <td>Vim</td>
#       <td>+RglMHb<br>+EPN-T<br>+Rgl<br>+RglFb<br>+EPN-Ep<br></td>
#       <td>Hbb-bs</td>
#       <td></td>
#       <td>C1qa</td>
#       <td></td>
#       <td>Rgs5</td>
#       <td>+PERI<br>-RglMHb<br>-Rgl<br>-RglFb<br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Rtn1</td>
#       <td></td>
#       <td>Igfbpl1</td>
#       <td>+NProg<br>+NblastM<br></td>
#       <td>H3f3b</td>
#       <td></td>
#       <td>Nxph1</td>
#       <td>+IntHc1<br>+IntMid1<br>+NbIntTG2<br>+NbIntTG1<br></td>
#       <td>Lef1</td>
#       <td></td>
#       <td>Rps11</td>
#       <td></td>
#       <td>Lhx5</td>
#       <td>+@Hem<br>+CRC<br></td>
#       <td>Tuba1a</td>
#       <td></td>
#       <td>Six3</td>
#       <td>+@Eye<br>-MGabaProg<br>+ANE<br>+IntMid1<br>+MSN1<br>+NbRtC<br></td>
#       <td>Phgdh</td>
#       <td></td>
#       <td>Itm2a</td>
#       <td></td>
#       <td>Hbb-bt</td>
#       <td></td>
#       <td>Trem2</td>
#       <td></td>
#       <td>Mmp9</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Ndn</td>
#       <td></td>
#       <td>Tubb5</td>
#       <td></td>
#       <td>Adarb2</td>
#       <td>+CGEInt<br>+Glyc-Cblc2<br>+IntFV1<br></td>
#       <td>Gad2</td>
#       <td>+@GABAGLUT1<br>+@GABA<br>+Glyc-Cblc2<br></td>
#       <td>Lmo3</td>
#       <td>+NbFor4<br>+NbMid3<br></td>
#       <td>Rpl13a</td>
#       <td></td>
#       <td>Tfap2b</td>
#       <td>+NbTG3a<br>+NbIntTG2<br>+NbTG1<br>+NbTG2<br>+NbIntTG1<br>+NbHin5<br>+NbTG3b<br></td>
#       <td>Gap43</td>
#       <td></td>
#       <td>Npy</td>
#       <td>+@AGRP<br>-IntMid2<br>+IntMid1<br>+OB-OEC<br></td>
#       <td>Ckb</td>
#       <td></td>
#       <td>Serpinh1</td>
#       <td></td>
#       <td>Hba-a2</td>
#       <td>+ERY<br></td>
#       <td>Cx3cr1</td>
#       <td></td>
#       <td>Ndufa4l2</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Ly6h</td>
#       <td></td>
#       <td>Sox11</td>
#       <td></td>
#       <td>Malat1</td>
#       <td></td>
#       <td>Nrxn3</td>
#       <td>+Glyc-Skor1<br>+IntHc1<br></td>
#       <td>Islr2</td>
#       <td>+IntHin1<br>+NbMid3<br></td>
#       <td>Rps6</td>
#       <td></td>
#       <td>Gad2</td>
#       <td>+@GABAGLUT1<br>+@GABA<br>+Glyc-Cblc2<br></td>
#       <td>Nnat</td>
#       <td></td>
#       <td>Uncx</td>
#       <td>+MB<br>+NbFor1<br></td>
#       <td>Plpp3</td>
#       <td></td>
#       <td>Rps27</td>
#       <td></td>
#       <td>Hba-a1</td>
#       <td></td>
#       <td>Pld4</td>
#       <td></td>
#       <td>Cald1</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
